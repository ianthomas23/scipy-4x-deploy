# %%
import numpy as np
import scipy.integrate as integrate
import scipy.special as special

# %%
integrate.quad(lambda x: special.jv(2.5,x), 0, 4.5)

# %%
I = np.sqrt(2/np.pi)*(18.0/27*np.sqrt(2)*np.cos(4.5) - 4.0/27*np.sqrt(2)*np.sin(4.5) + np.sqrt(2*np.pi) * special.fresnel(3/np.sqrt(np.pi))[0])
I

# %%
def integrand(x, a, b):
    return a*x**2 + b

a = 2
b = 1
integrate.quad(integrand, 0, 1, args=(a,b))
