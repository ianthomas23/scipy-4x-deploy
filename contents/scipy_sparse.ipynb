# %%
import scipy

# %%
A = scipy.sparse.csc_array([[1, 0, 0.1], [0, 0.2, 0], [1, 0, 2]])

# %%
Ainv = scipy.sparse.linalg.inv(A)

# %%
A.todense(), Ainv.todense()

# %%
scipy.sparse.linalg.spsolve(A, [1.1, 0.2, -0.3])
